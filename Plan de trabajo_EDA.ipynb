# %% [markdown]
# # Plan de trabajo Proyecto final
#
# ## EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
contract = pd.read_csv('/datasets/contract.csv')
internet = pd.read_csv('/datasets/internet.csv')
personal = pd.read_csv('/datasets/personal.csv')
phone = pd.read_csv('/datasets/phone.csv')

# %% [markdown]
# ## Personal

# %%
print(personal.info())
print()
print('Shape:',personal.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# None
#
# Shape: (7043, 5)

# %%
personal.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Distribución de clientes por genero 
sns.countplot(x='gender', data=personal)
plt.title('Distribución por género')
plt.show()

# %% [markdown]
# ## Contract

# %%
print(contract.info())
print()
print('Shape:',contract.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
# None
#
# Shape: (7043, 8)

# %%
contract.head()
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65

# %% [markdown]
# Distribución de contratos y de cargos mensuales

# %%
sns.countplot(x='Type', data=contract)
plt.title('Tipo de contrato')
plt.show()

sns.histplot(contract['MonthlyCharges'], kde=True)
plt.title('Distribución de cargos mensuales')
plt.show()

# %% [markdown]
# ## Phone

# %%
print(phone.info())
print()
print('Shape:',phone.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# None
#
# Shape: (6361, 2)

# %%
phone.head()
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %% [markdown]
# Detalle de líneas

# %%
sns.countplot(x='MultipleLines', data=phone)
plt.title('Múltiples líneas telefónicas')
plt.show()

# %% [markdown]
# ## Internet

# %%
print(internet.info())
print()
print('Shape:',internet.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB
# None
#
# Shape: (149396, 5)

# %%
internet.head()
# Out:
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000

# %% [markdown]
# Nota: El archivo Internet no tiene campo relacionado con los demás archivos, y tiene estructura diferente al que viene en el paquete que se descarga

# %% [markdown]
# ## Lista de preguntas
#
# * ¿Qué tipo de servicio tiene mayor abandono?
# * ¿Qué tipo de personas contratan ambos servicios, y cuales contratan?
# * ¿Qué tipo de contrato tiene mayor abandono?
# * ¿El total de cargos influye en el abandono?

# %% [markdown]
# # Plan de trabajo
#
# 1. Definición del problema
#    * Objetivo: Predecir si un cliente cancela contrato
#    * Tipo de problema: Clasificación binaria
# 2. Exploración y preparación de datos
#     * EDA (ya realizado)
# 3. Ingenieria de datos
#     * Creación de nuevas variables y codificación de variables categoricas
# 4. Preparación de dataset
#     * Separación de datos en entrenamiento y prueba
# 5. Entrenamiento de modelos
#     * Entrenamiento de diversos modelos para comprobar cual seria el mejor
# 6. Evaluación de modelos
#     * Se van a utilizar metricas como f1-score, ROC_AUC
# 7. Predicción y análisis de resultados
#     * Conclusiones generales

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Fortalezas del plan de trabajo</b> <a class="tocSkip"></a><br>
# Has hecho un muy buen inicio de proyecto. Se reconoce que:
#
# • Has integrado y cargado correctamente las bases de datos necesarias para el análisis.<br>
# • Realizaste una EDA clara, estructurada y con visualizaciones útiles para entender las variables clave.<br>
# • Estás planteando un objetivo de negocio claro: predecir la cancelación de contrato por parte de los clientes.<br>
# • Has formulado preguntas orientadoras que muestran una intención analítica alineada con el objetivo del proyecto.<br>
# • Tu plan de trabajo está ordenado por etapas lógicas que corresponden al flujo de un proyecto real de ciencia de datos.<br>
# • Consideras tanto la ingeniería de variables como la evaluación de múltiples modelos, lo cual es positivo.<br>
# • Incluyes métricas apropiadas para problemas de clasificación como el F1-score y el AUC-ROC.
#
# ¡Buen trabajo hasta aquí!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"> <b>Oportunidades de mejora y recomendaciones técnicas</b> <a class="tocSkip"></a><br>
# • Si bien tu objetivo general está claro, sería útil especificar a quién le serviría esta predicción (por ejemplo, el área de retención, ventas, etc.). Esto le dará un enfoque más “de negocio” a tu proyecto.
# • En el paso de ingeniería de datos, te sugiero que anticipes qué variables podrían ser útiles para derivar nuevas características. Por ejemplo, ¿podrías agrupar ciertos servicios en categorías? ¿O crear una variable que indique la antigüedad del cliente si tienes las fechas necesarias?
# • Asegúrate de considerar la posibilidad de desbalanceo en la variable objetivo. Si el número de cancelaciones es bajo en comparación con los que permanecen, deberás ajustar el enfoque con técnicas como: stratified sampling, oversampling, o usar métricas más robustas que la simple accuracy.
# • Aunque mencionas que vas a probar varios modelos, aún no detallas cuáles. Sería valioso que los anticipes (por ejemplo, Random Forest, Logistic Regression, Gradient Boosting, etc.) para mostrar una planeación técnica más profunda.
# • Faltaría mencionar la validación cruzada en la evaluación del modelo. Este paso es importante para verificar la estabilidad del desempeño de tu modelo más allá de una sola partición train-test.
# • Te animo también a incluir una sección al final del proyecto con recomendaciones accionables basadas en los hallazgos. ¿Qué le sugerirías a la empresa para reducir el churn, con base en tu modelo y análisis?
#
#
#
# </div>
