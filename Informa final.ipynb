# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # Proyecto Final
# ## Informe de solución

# %% [markdown]
# ### Pasos realizados del plan de trabajo.
#
# 1. Definición del problema.
#     Se realizó la definición identificando el objetivo y el tipo de problema a resolver
#     * Objetivo: Predecir si un cliente cancela contrato
#     * Tipo de problema: Clasificación binaria
# 2. Exploración y preparación de datos.
#     Se realizó un EDA  obteniendo info(), shape(), head() de cada archivo csv (personal, contract, phone e internet), así como gráficos como:
#     * Distribución de clientes por genero
#     * Distribución por tipo de contratos y cargos mensuales
#     * Distribución por tipo de líneas contratadas, multiples, si-no
#     * Distribución de servicios contratados por cliente
# 3. Ingenieria de datos.
#     Se realizó creación de nuevas columnas variables y se codificaron las variables categóricas
#     * Se creó la columna 'Churn' identificando si el cliente esta o no activo, tomando en cuenta la columna fecha final del archivo contract.
#     * Se utilizó get_dummies() para caodificar las variables categóricas
# 4. Preparación del dataset
#     * Se juntaron los csv con los datos preparados por medio del campo 'customerID'
#     * Por medio de train_test_split() se separaron los datos en entrenamiento y prueba
# 5. Entrenamiento de modelos
#     * Se entrenó modelo de regresión logistica
#     * Se entrenó modelo Random Forest con 200 estimadores
#     * Se entrenó modelo XGBClassifier con métrica de evaluación 'logloss'
# 6. Evaluación de modelos
#     Se realizó comparación de modelos siguiendo el siguiente procedimiento:
#     * Se entrenaron modelos con los datos de entrenamiento
#     * Se realizó predicción con datos de prueba
#     * Se realizó gráfico para comparar resultados de las métricas
# 7. Predicción y análisis de resultados
#     * Se realizaron conclusiones generales

# %% [markdown]
# ### Dificultades encontradas
#
# 1. En el paso de de ingeniería de datos, se encontró que al intentar normalizar el archivo contract, la columna 'TotalCharges' tenía campos vacíos, es decir ' ', por lo que se realizó el siguiente procedimiento:
#     * Reemplazar los espacios vacíos por NaN
#     * Convertir 'TotalCharges' a numérico
#     * Reemplazar los nulos por 0
# 2. En el paso de entrenamiento de modelos se encontró fuga de datos ya que todas las métricas daban como resultado 1.0, se realizó lo siguiente:
#     * Prueba con modelo dummy y con validación cruzada
#     * Se realizó función para identificar las columnas culpables de la fuga
#     * Se identificaron y eliminaron las columnas culpables 'CustomerTenureMonths' y 'AvgMonthlySpent'

# %% [markdown]
# ### Pasos Clave
#
# A continuación enlisto los que considero los puntos clave para resolver la tarea.
#
# 1. Identificar la tarea objetivo y el tipo de clasificación
# 2. Creación de la columna churn
# 3. Identificar la fuga de datos

# %% [markdown]
# ### Modelo final
#
# El modelo que se considero el definitivo fue el de regresión logística, ya que fue el que mejor evaluación tuvo en las métricas F1 y ROC AUC obteniendo los siguientes resultados:
# * F1 = `0.612`
# * ROC AUC = `0.812`
#
# También obtuvo los mejores resultados en precision y recall obteniendo:
# * presicion = `0.652`
# * recall = `0.581`

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> -
#
#  **gran proyecto**. Tu trabajo muestra una estructura clara y bien organizada en cada paso del plan de trabajo, desde la definición del problema hasta la predicción y análisis de resultados. Se nota que pusiste atención en la preparación de datos, la creación de nuevas variables y la comparación de distintos modelos, lo cual es fundamental en un proyecto de ciencia de datos.
#
# Como siguiente paso en tu desarrollo, te recomiendo ampliar tu comprensión del **entorno tecnológico en general**. Dominar el modelado es un gran inicio, pero también es importante entender cómo todo esto se integra en proyectos real;
#
# * **Modelos de Lenguaje (LLMs)** → cómo funcionan y cómo se pueden aplicar a diferentes problemas.
# * **APIs** → aprender a consumir y diseñar APIs para conectar modelos con aplicaciones.
# * **Cloud Computing** → conocer servicios en la nube que permiten desplegar modelos y escalar proyectos (AWS, GCP, Azure).
#
# Estas habilidades te darán una visión más completa del ciclo de vida de un proyecto de ciencia de datos, desde la experimentación hasta el despliegue en entornos reales.
#
#
#
# </div>
